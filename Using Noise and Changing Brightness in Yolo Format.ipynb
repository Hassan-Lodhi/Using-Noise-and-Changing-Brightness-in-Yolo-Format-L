# %%
import cv2
import numpy as np 
import json
import matplotlib.pyplot as plt
import os

# %%
input_dir = 'cat_dog'
output_dir = 'augmented_images'

# %%
# split the original images into two groups for augmentation
brightness_images = ['cat1.jpg', 'cat2.jpg', 'cat3.jpg']
noise_images = ['dog1.jpg', 'dog2.jpg', 'dog3.jpg', 'dog4.jpg']

# %%
# Augment brightness pics
for filename in os.listdir(input_dir):
    if filename.endswith('.jpeg'):
        img = cv2.imread(os.path.join(input_dir, filename))
        for i in range(5):
            alpha = np.random.uniform(0.5, 1.5)
            beta = np.random.randint(-50, 50)
            bright_img = cv2.addWeighted(img, alpha, np.zeros(img.shape, img.dtype), 0, beta)
            output_filename = os.path.splitext(filename)[0] + '_brightness_' + str(i) + '.jpeg'
            cv2.imwrite(os.path.join(output_dir, output_filename), bright_img)

print("35 Images with Brightness are genrated")
# Out:
# 35 Images with Brightness are genrated

# %%
for i in range(11):
        alpha = np.random.uniform(0.5, 1.5)
        beta = np.random.randint(-50, 50)
        bright_img = cv2.addWeighted(img, alpha, np.zeros(img.shape, img.dtype), 0, beta)

# %%
bright_img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
plt.imshow(bright_img)

# %%
for img_key, bright_img['_via_img_metadata'].items():

    img_filename = img_values['filename']
    image = cv2.imread(img_filename)
    
    img_height, img_width = image.shape[:2]
    
    with open(os.path.join('Yolo_Format', os.path.splitext(img_filename)[0] + '.txt'), 'w') as f:
      
        for obj in img_values['regions']:
            
            class_label = list(obj['region_attributes']['class'])[0]
            bbox = obj['shape_attributes']
            
            print(bbox)
           
            x_center = (bbox['x'] + bbox['width'] / 2) / img_width
            y_center = (bbox['y'] + bbox['height'] / 2) / img_height
            width = bbox['width'] / img_width
            height = bbox['height'] / img_height


            class_index = class_names.index(class_label)
            f.write(f"{class_index} {x_center} {y_center} {width} {height}\n")
# Out:
#   Cell In[21], line 1
#     for img_key, bright_img['_via_img_metadata'].items():
#                  ^
# SyntaxError: cannot assign to function call
